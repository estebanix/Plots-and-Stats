# %%
from plots.plot_demographic_composition import plot_demographic_composition
from plots.variable_distribution import variable_distribution
from plots.percentage_portion_distrubition_kde import percentage_portion_distribution_kde
import pandas as pd

# %%
df = pd.read_csv("example_datasets/example_dataset.csv")

# %%
df.head()
# Out:
#     Sample  87Sr/86Sr       2SE     Sex Class         dating specimen  \
# 0  sample1   0.712345  0.000008    Male     A   Early_Bronze   enamel
# 1  sample2   0.710987  0.000007  Female     A   Early_Bronze   enamel
# 2  sample3   0.711245  0.000006    Male     B  Middle_Bronze   enamel
# 3  sample4   0.709876  0.000009  Female     B  Middle_Bronze   enamel
# 4  sample5   0.710123  0.000008    Male     A  Middle_Bronze   enamel
#
#           site
# 0  ExampleSite
# 1  ExampleSite
# 2  ExampleSite
# 3  ExampleSite
# 4  ExampleSite

# %%
dating_order = ["Early_Bronze", "Middle_Bronze", "Late_Bronze"]

# %%
plot_demographic_composition(df, dating_order)

# %%
variable_distribution(df, variable="87Sr/86Sr", hue_dif="Class", ax_value=0.711)

# %%
percentage_portion_distribution_kde(df, target_variable="87Sr/86Sr", grouping_variable="dating", threshold=0.7115, grouping_order=dating_order)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joypy/joyplot.py:176: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = data.groupby(by)
# /Users/kertez/Documents/VS/Plots-and-Stats/plots/percentage_portion_distrubition_kde.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   groups = df.groupby(group_by_var)
